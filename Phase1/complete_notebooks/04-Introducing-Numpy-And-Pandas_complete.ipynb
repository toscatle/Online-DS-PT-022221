# %% [markdown]
# # Using Python Libraries

# %% [markdown]
# ## First Up: Numeric Python

# %% [markdown]
# ![numpy](https://raw.githubusercontent.com/donnemartin/data-science-ipython-notebooks/master/images/numpy.png)
#
# [NumPy](https://www.numpy.org/) is the fundamental package for scientific computing with Python. Many other data science packages, especially those that work with matrices, rely on it for its speed and utility.

# %% [markdown]
# For numpy, the standard alias is `np`.

# %%
# Import numpy
import numpy as np

# %% [markdown]
# ### NumPy Arrays
#
# Python lists and NumPy arrays can both hold numbers. However, Python lists have limited functionality for mathematical operations. NumPy arrays make it easy and fast to do math with a collection of numbers.

# %%
# Explore a numpy array
x = np.array([1, 2, 3])
print(x)
print(type(x))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>

# %% [markdown]
# Let's make a list using base Python, and an array using Numpy, and see how they function differently:

# %%
# Create a list in base Python of 3 integers
numbers_list = [2, 4, 6]
# Create a numpy array containing the same 3 integers
numbers_array = np.array([2, 4, 6])

# %% [markdown]
# ### Arithmetic Operations
#
# Arithmetic operators (e.g. +, -, * and /) work according to mathematical principles for arrays, unlike with lists. These operations are done "element-wise".

# %%
# Multiply the array by 3
numbers_array * 3
# Out:
# array([ 6, 12, 18])

# %%
# Multiply the list by 3
numbers_list * 3
# Out:
# [2, 4, 6, 2, 4, 6, 2, 4, 6]

# %%
# Add 20 to the array
numbers_array + 20
# Out:
# array([22, 24, 26])

# %%
# Add 20 to the list
numbers_list + 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e2db3d4c6fdb> in <module>
#       1 # Add 20 to the list
# ----> 2 numbers_list + 20
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# ### Speed
#
# Below, you will find a piece of code we will use to compare the speed of operations on lists vs arrays.

# %%
# Setting the size of our iterables
size_of_vec = 1000

# Creating two lists of that size
X = list(range(size_of_vec))
Y = list(range(size_of_vec))

# %%
# Timing how long it takes to add each element in the two lists
# Complicated bit of code using a list comprehension
# %timeit [X[i] + Y[i] for i in range(size_of_vec)]
# Out:
# 92 µs ± 1.35 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# Now let's try with numpy arrays
X = np.array(range(size_of_vec))
Y = np.array(range(size_of_vec))

# %%
# Much simpler code, since it's easier to do element-wise math
# %timeit X + Y
# Out:
# 835 ns ± 16 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## Next Up: Importing, Reading and Manipulating Data with ACTUAL LITERAL PANDAS
#
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - but Pandas is a great library to work with relational data.
#
# [Check out the documentation!](https://pandas.pydata.org/pandas-docs/stable/) (always a great idea)

# %% [markdown]
# Note that we didn't go into a lot of Numpy's functionality, but here's something cool - Pandas is built on top of Numpy! That means they work really well together, and that Pandas has some math functionality already built in.
#
# If you'd like to read more about Numpy and Pandas, [here is an interesting blog post](https://cloudxlab.com/blog/numpy-pandas-introduction/) discussing them.

# %% [markdown]
# Let's dive into some data from the Austin Animal Shelter.
#
# Data source: [intakes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) and [outcomes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238).
#
# Today we'll be working with the intakes data, which I've already downloaded and included in the repository.

# %%
# Import
import pandas as pd

# %% [markdown]
# Before reading in the data, we need to know what format the data is in and where exactly the data can be found, so we can tell Pandas what to do.

# %%
# Where is our data?
# !ls data/
# Out:
# Austin_Animal_Center_Intakes_030921.csv
# Austin_Animal_Center_Outcomes_030921.csv

# %%
# Read in the comma-separated-value (csv) document as df
df = pd.read_csv('data/Austin_Animal_Center_Intakes_030921.csv', 
                 parse_dates=['DateTime'])

# %% [markdown]
# What options do we have when we read in a csv? Let's look at the documentation!
#
# [Convenient link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#
# I happen to know that there is a column in the data named 'DateTime' (run the below code to check it out before adjusting our read-in code!) - let's use an argument to read it in as a datetime object, then discuss.

# %%
df['DateTime']
# Out:
# 0        2019-01-03 16:19:00
# 1        2015-07-05 12:59:00
# 2        2016-04-14 18:43:00
# 3        2013-10-21 07:59:00
# 4        2014-06-29 10:38:00
#                  ...
# 124217   2021-03-09 12:07:00
# 124218   2021-03-09 12:40:00
# 124219   2021-03-05 14:31:00
# 124220   2021-03-09 12:04:00
# 124221   2021-03-05 14:31:00
# Name: DateTime, Length: 124222, dtype: datetime64[ns]

# %% [markdown]
# ### Initial Exploration of a Dataframe
#
# Questions to ask yourself:
#
# - How big is the data?
# - Are there any empty cells?
# - What are the datatypes of the columns of data?

# %%
# What does this dataframe look like?
# Check out the first 5 rows
df.head(3)
# Out:
#   Animal ID     Name            DateTime               MonthYear  \
# 0   A786884   *Brock 2019-01-03 16:19:00  01/03/2019 04:19:00 PM
# 1   A706918    Belle 2015-07-05 12:59:00  07/05/2015 12:59:00 PM
# 2   A724273  Runster 2016-04-14 18:43:00  04/14/2016 06:43:00 PM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color
# 0     Tricolor
# 1  White/Liver
# 2  Sable/White

# %%
df.tail()
# Out:
#        Animal ID     Name            DateTime               MonthYear  \
# 124217   A830428      NaN 2021-03-09 12:07:00  03/09/2021 12:07:00 PM
# 124218   A830411      NaN 2021-03-09 12:40:00  03/09/2021 12:40:00 PM
# 124219   A830250  *Hansel 2021-03-05 14:31:00  03/05/2021 02:31:00 PM
# 124220   A830431    Chema 2021-03-09 12:04:00  03/09/2021 12:04:00 PM
# 124221   A830251  *Gretel 2021-03-05 14:31:00  03/05/2021 02:31:00 PM
#
#                                      Found Location      Intake Type  \
# 124217            501 Strichen Drive in Travis (TX)         Wildlife
# 124218               12609 Dessau Rd in Austin (TX)            Stray
# 124219  Cesar Chavez And North Lamar in Austin (TX)            Stray
# 124220                                  Austin (TX)  Owner Surrender
# 124221  Cesar Chavez And North Lamar in Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 124217             Sick       Other         Unknown         2 years
# 124218           Normal         Dog     Intact Male          1 year
# 124219           Normal         Dog     Intact Male         4 years
# 124220           Normal         Dog         Unknown         3 years
# 124221           Normal         Dog   Intact Female         2 years
#
#                              Breed        Color
# 124217                       Skunk  Black/White
# 124218       Dachshund/Rat Terrier  Brown/White
# 124219             German Shepherd  Brown/Black
# 124220  Beagle/Chihuahua Shorthair  Black/Brown
# 124221             German Shepherd  Brown/Black

# %%
# Check out the shape of the df
df.shape
# Out:
# (124222, 12)

# %%
# And then the size
df.size
# Out:
# 1490664

# %%
# And then look at some info on the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124222 entries, 0 to 124221
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         124222 non-null  object
#  1   Name              85158 non-null   object
#  2   DateTime          124222 non-null  datetime64[ns]
#  3   MonthYear         124222 non-null  object
#  4   Found Location    124222 non-null  object
#  5   Intake Type       124222 non-null  object
#  6   Intake Condition  124222 non-null  object
#  7   Animal Type       124222 non-null  object
#  8   Sex upon Intake   124221 non-null  object
#  9   Age upon Intake   124222 non-null  object
#  10  Breed             124222 non-null  object
#  11  Color             124222 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.4+ MB

# %%
# Describe the columns
df.describe()
# Out:
# <ipython-input-21-daaa70c92779>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#        Animal ID   Name             DateTime               MonthYear  \
# count     124222  85158               124222                  124222
# unique    111013  19758                87743                   87743
# top      A721033    Max  2016-09-23 12:00:00  09/23/2016 12:00:00 PM
# freq          33    564                   64                      64
# first        NaN    NaN  2013-10-01 07:51:00                     NaN
# last         NaN    NaN  2021-03-09 12:50:00                     NaN
#
#        Found Location Intake Type Intake Condition Animal Type  \
# count          124222      124222           124222      124222
# unique          53737           6               10           5
# top       Austin (TX)       Stray           Normal         Dog
# freq            22889       86507           108026       70505
# first             NaN         NaN              NaN         NaN
# last              NaN         NaN              NaN         NaN
#
#        Sex upon Intake Age upon Intake                   Breed        Color
# count           124221          124222                  124222       124222
# unique               5              52                    2632          595
# top        Intact Male          1 year  Domestic Shorthair Mix  Black/White
# freq             40349           21809                   30985        13039
# first              NaN             NaN                     NaN          NaN
# last               NaN             NaN                     NaN          NaN

# %% [markdown]
# **A note on `.describe()`:** this function behaves differently whether we feed in objects or numeric types. We'll explore this more later.
#
# **And a question:** You see that some of the ways we dealt with our dataframe required `()` and some did not - why is that?
#
# - Methods vs attributes

# %% [markdown]
# ### Accessing Columns
#
# Use brackets and the exact column name to access a particular column.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'].head()
# Out:
# 0     *Brock
# 1      Belle
# 2    Runster
# 3        NaN
# 4        Rio
# Name: Name, dtype: object

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Name']].head()
# Out:
#       Name
# 0   *Brock
# 1    Belle
# 2  Runster
# 3      NaN
# 4      Rio

# %% [markdown]
# Can also use `.` notation, if the column name doesn't have spaces.

# %%
df.Name
# Out:
# 0          *Brock
# 1           Belle
# 2         Runster
# 3             NaN
# 4             Rio
#            ...
# 124217        NaN
# 124218        NaN
# 124219    *Hansel
# 124220      Chema
# 124221    *Gretel
# Name: Name, Length: 124222, dtype: object

# %% [markdown]
# ### Dealing with Datetime Objects
#
# You can access parts of a datetime object using `.dt` - an attribute of the column, not a method!

# %%
df.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color'],
#       dtype='object')

# %%
df['MonthYear']
# Out:
# 0         01/03/2019 04:19:00 PM
# 1         07/05/2015 12:59:00 PM
# 2         04/14/2016 06:43:00 PM
# 3         10/21/2013 07:59:00 AM
# 4         06/29/2014 10:38:00 AM
#                    ...
# 124217    03/09/2021 12:07:00 PM
# 124218    03/09/2021 12:40:00 PM
# 124219    03/05/2021 02:31:00 PM
# 124220    03/09/2021 12:04:00 PM
# 124221    03/05/2021 02:31:00 PM
# Name: MonthYear, Length: 124222, dtype: object

# %%
# Let's check out the intake year
df['DateTime'].dt.year
# Out:
# 0         2019
# 1         2015
# 2         2016
# 3         2013
# 4         2014
#           ...
# 124217    2021
# 124218    2021
# 124219    2021
# 124220    2021
# 124221    2021
# Name: DateTime, Length: 124222, dtype: int64

# %%
# How do we create a new column?
# Let's create a new column for intake year
df['IntakeYear'] = df['DateTime'].dt.year

# %%
# Check our work
df.head()
# Out:
#   Animal ID     Name            DateTime               MonthYear  \
# 0   A786884   *Brock 2019-01-03 16:19:00  01/03/2019 04:19:00 PM
# 1   A706918    Belle 2015-07-05 12:59:00  07/05/2015 12:59:00 PM
# 2   A724273  Runster 2016-04-14 18:43:00  04/14/2016 06:43:00 PM
# 3   A665644      NaN 2013-10-21 07:59:00  10/21/2013 07:59:00 AM
# 4   A682524      Rio 2014-06-29 10:38:00  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color  IntakeYear
# 0                             Beagle Mix     Tricolor        2019
# 1               English Springer Spaniel  White/Liver        2015
# 2                            Basenji Mix  Sable/White        2016
# 3                 Domestic Shorthair Mix       Calico        2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014

# %%
# What datatype is the data in our new column?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124222 entries, 0 to 124221
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         124222 non-null  object
#  1   Name              85158 non-null   object
#  2   DateTime          124222 non-null  datetime64[ns]
#  3   MonthYear         124222 non-null  object
#  4   Found Location    124222 non-null  object
#  5   Intake Type       124222 non-null  object
#  6   Intake Condition  124222 non-null  object
#  7   Animal Type       124222 non-null  object
#  8   Sex upon Intake   124221 non-null  object
#  9   Age upon Intake   124222 non-null  object
#  10  Breed             124222 non-null  object
#  11  Color             124222 non-null  object
#  12  IntakeYear        124222 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 12.3+ MB

# %% [markdown]
# ### Checking for Null Values
#
# Can use `.isna` or `.isnull` - same thing!

# %%
# Check it - is the result what you expect?
df.isna()
# Out:
#         Animal ID   Name  DateTime  MonthYear  Found Location  Intake Type  \
# 0           False  False     False      False           False        False
# 1           False  False     False      False           False        False
# 2           False  False     False      False           False        False
# 3           False   True     False      False           False        False
# 4           False  False     False      False           False        False
# ...           ...    ...       ...        ...             ...          ...
# 124217      False   True     False      False           False        False
# 124218      False   True     False      False           False        False
# 124219      False  False     False      False           False        False
# 124220      False  False     False      False           False        False
# 124221      False  False     False      False           False        False
#
#         Intake Condition  Animal Type  Sex upon Intake  Age upon Intake  \
# 0                  False        False            False            False
# 1                  False        False            False            False
# 2                  False        False            False            False
# 3                  False        False            False            False
# 4                  False        False            False            False
# ...                  ...          ...              ...              ...
# 124217             False        False            False            False
# 124218             False        False            False            False
# 124219             False        False            False            False
# 124220             False        False            False            False
# 124221             False        False            False            False
#
#         Breed  Color  IntakeYear
# 0       False  False       False
# 1       False  False       False
# 2       False  False       False
# 3       False  False       False
# 4       False  False       False
# ...       ...    ...         ...
# 124217  False  False       False
# 124218  False  False       False
# 124219  False  False       False
# 124220  False  False       False
# 124221  False  False       False
#
# [124222 rows x 13 columns]

# %%
# How can you make that result more usable?
df.isna().sum()
# Out:
# Animal ID               0
# Name                39064
# DateTime                0
# MonthYear               0
# Found Location          0
# Intake Type             0
# Intake Condition        0
# Animal Type             0
# Sex upon Intake         1
# Age upon Intake         0
# Breed                   0
# Color                   0
# IntakeYear              0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicate Rows

# %%
# Function is called duplicated - check the documentation!
df.duplicated(subset=['Name'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 124217     True
# 124218     True
# 124219     True
# 124220     True
# 124221     True
# Length: 124222, dtype: bool

# %%
# Can use same trick as above on duplicated to make the result more usable
df.duplicated(subset=['Name'], keep=False).sum()
# Out:
# 113284

# %% [markdown]
# ### Dropping Columns or Rows
#
# Several different methods depending on what we're doing - but the to discuss right now is `.drop`

# %%
# Let's drop the MonthYear column, which is the same as our DateTime
df = df.drop(columns=['MonthYear'])

# %%
# Check our work here...
df.head()
# Out:
#   Animal ID     Name            DateTime                       Found Location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    Breed        Color  IntakeYear
# 0                             Beagle Mix     Tricolor        2019
# 1               English Springer Spaniel  White/Liver        2015
# 2                            Basenji Mix  Sable/White        2016
# 3                 Domestic Shorthair Mix       Calico        2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014

# %% [markdown]
# Why won't my changes save ???
#
# Fun thing about pandas - time to discuss resetting variables, or using `inplace`

# %% [markdown]
# ### Renaming Columns
#
# [Documentation for `.rename`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html)

# %%
# Let's remove spaces from the columns, and make all column names lowercase to be easier
# Can use a dictionary to rename
col_names = df.columns

# %%
col_names[0].replace(" ", "")
# Out:
# 'AnimalID'

# %%
new_col_names = []
for c in col_names:
    new_col_names.append(c.replace(" ", "").lower())

# %%
new_col_names
# Out:
# ['animalid',
#  'name',
#  'datetime',
#  'foundlocation',
#  'intaketype',
#  'intakecondition',
#  'animaltype',
#  'sexuponintake',
#  'ageuponintake',
#  'breed',
#  'color',
#  'intakeyear']

# %%
col_dict = dict(zip(col_names, new_col_names))

# %%
col_dict
# Out:
# {'Animal ID': 'animalid',
#  'Name': 'name',
#  'DateTime': 'datetime',
#  'Found Location': 'foundlocation',
#  'Intake Type': 'intaketype',
#  'Intake Condition': 'intakecondition',
#  'Animal Type': 'animaltype',
#  'Sex upon Intake': 'sexuponintake',
#  'Age upon Intake': 'ageuponintake',
#  'Breed': 'breed',
#  'Color': 'color',
#  'IntakeYear': 'intakeyear'}

# %%
df = df.rename(col_dict, axis=1)

# %%
# Check your work
df.head()
# Out:
#   animalid     name            datetime                        foundlocation  \
# 0  A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1  A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2  A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3  A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4  A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intaketype intakecondition animaltype  sexuponintake ageuponintake  \
# 0      Stray          Normal        Dog  Neutered Male       2 years
# 1      Stray          Normal        Dog  Spayed Female       8 years
# 2      Stray          Normal        Dog    Intact Male     11 months
# 3      Stray            Sick        Cat  Intact Female       4 weeks
# 4      Stray          Normal        Dog  Neutered Male       4 years
#
#                                    breed        color  intakeyear
# 0                             Beagle Mix     Tricolor        2019
# 1               English Springer Spaniel  White/Liver        2015
# 2                            Basenji Mix  Sable/White        2016
# 3                 Domestic Shorthair Mix       Calico        2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014

# %%
# Can also use a lambda function
df.rename(columns= lambda x: x.replace(" ", "").lower())
# Out:
#        animalid     name            datetime  \
# 0       A786884   *Brock 2019-01-03 16:19:00
# 1       A706918    Belle 2015-07-05 12:59:00
# 2       A724273  Runster 2016-04-14 18:43:00
# 3       A665644      NaN 2013-10-21 07:59:00
# 4       A682524      Rio 2014-06-29 10:38:00
# ...         ...      ...                 ...
# 124217  A830428      NaN 2021-03-09 12:07:00
# 124218  A830411      NaN 2021-03-09 12:40:00
# 124219  A830250  *Hansel 2021-03-05 14:31:00
# 124220  A830431    Chema 2021-03-09 12:04:00
# 124221  A830251  *Gretel 2021-03-05 14:31:00
#
#                                       foundlocation       intaketype  \
# 0               2501 Magin Meadow Dr in Austin (TX)            Stray
# 1                  9409 Bluegrass Dr in Austin (TX)            Stray
# 2                2818 Palomino Trail in Austin (TX)            Stray
# 3                                       Austin (TX)            Stray
# 4                     800 Grove Blvd in Austin (TX)            Stray
# ...                                             ...              ...
# 124217            501 Strichen Drive in Travis (TX)         Wildlife
# 124218               12609 Dessau Rd in Austin (TX)            Stray
# 124219  Cesar Chavez And North Lamar in Austin (TX)            Stray
# 124220                                  Austin (TX)  Owner Surrender
# 124221  Cesar Chavez And North Lamar in Austin (TX)            Stray
#
#        intakecondition animaltype  sexuponintake ageuponintake  \
# 0               Normal        Dog  Neutered Male       2 years
# 1               Normal        Dog  Spayed Female       8 years
# 2               Normal        Dog    Intact Male     11 months
# 3                 Sick        Cat  Intact Female       4 weeks
# 4               Normal        Dog  Neutered Male       4 years
# ...                ...        ...            ...           ...
# 124217            Sick      Other        Unknown       2 years
# 124218          Normal        Dog    Intact Male        1 year
# 124219          Normal        Dog    Intact Male       4 years
# 124220          Normal        Dog        Unknown       3 years
# 124221          Normal        Dog  Intact Female       2 years
#
#                                         breed        color  intakeyear
# 0                                  Beagle Mix     Tricolor        2019
# 1                    English Springer Spaniel  White/Liver        2015
# 2                                 Basenji Mix  Sable/White        2016
# 3                      Domestic Shorthair Mix       Calico        2013
# 4       Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014
# ...                                       ...          ...         ...
# 124217                                  Skunk  Black/White        2021
# 124218                  Dachshund/Rat Terrier  Brown/White        2021
# 124219                        German Shepherd  Brown/Black        2021
# 124220             Beagle/Chihuahua Shorthair  Black/Brown        2021
# 124221                        German Shepherd  Brown/Black        2021
#
# [124222 rows x 12 columns]

# %% [markdown]
# ### Slicing and Dicing
#
# Perhaps your biggest tool for exploring around your dataframes will be `.loc` (and it's accompanying `.iloc`). This allows you to use conditionals to explore your data!

# %%
df.head()
# Out:
#   animalid     name            datetime                        foundlocation  \
# 0  A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1  A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2  A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3  A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4  A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intaketype intakecondition animaltype  sexuponintake ageuponintake  \
# 0      Stray          Normal        Dog  Neutered Male       2 years
# 1      Stray          Normal        Dog  Spayed Female       8 years
# 2      Stray          Normal        Dog    Intact Male     11 months
# 3      Stray            Sick        Cat  Intact Female       4 weeks
# 4      Stray          Normal        Dog  Neutered Male       4 years
#
#                                    breed        color  intakeyear
# 0                             Beagle Mix     Tricolor        2019
# 1               English Springer Spaniel  White/Liver        2015
# 2                            Basenji Mix  Sable/White        2016
# 3                 Domestic Shorthair Mix       Calico        2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014

# %%
# Example: look only at animals with intake type 'Stray'
df.loc[df['intaketype'] == 'Stray']
# Out:
#        animalid      name            datetime  \
# 0       A786884    *Brock 2019-01-03 16:19:00
# 1       A706918     Belle 2015-07-05 12:59:00
# 2       A724273   Runster 2016-04-14 18:43:00
# 3       A665644       NaN 2013-10-21 07:59:00
# 4       A682524       Rio 2014-06-29 10:38:00
# ...         ...       ...                 ...
# 124211  A830432       NaN 2021-03-09 12:50:00
# 124214  A829340  `*Trixie 2021-02-08 14:44:00
# 124218  A830411       NaN 2021-03-09 12:40:00
# 124219  A830250   *Hansel 2021-03-05 14:31:00
# 124221  A830251   *Gretel 2021-03-05 14:31:00
#
#                                       foundlocation intaketype  \
# 0               2501 Magin Meadow Dr in Austin (TX)      Stray
# 1                  9409 Bluegrass Dr in Austin (TX)      Stray
# 2                2818 Palomino Trail in Austin (TX)      Stray
# 3                                       Austin (TX)      Stray
# 4                     800 Grove Blvd in Austin (TX)      Stray
# ...                                             ...        ...
# 124211                                  Austin (TX)      Stray
# 124214              8801 South Ih 35 in Austin (TX)      Stray
# 124218               12609 Dessau Rd in Austin (TX)      Stray
# 124219  Cesar Chavez And North Lamar in Austin (TX)      Stray
# 124221  Cesar Chavez And North Lamar in Austin (TX)      Stray
#
#        intakecondition animaltype  sexuponintake ageuponintake  \
# 0               Normal        Dog  Neutered Male       2 years
# 1               Normal        Dog  Spayed Female       8 years
# 2               Normal        Dog    Intact Male     11 months
# 3                 Sick        Cat  Intact Female       4 weeks
# 4               Normal        Dog  Neutered Male       4 years
# ...                ...        ...            ...           ...
# 124211          Normal        Cat  Intact Female       2 years
# 124214          Normal        Dog  Intact Female        1 year
# 124218          Normal        Dog    Intact Male        1 year
# 124219          Normal        Dog    Intact Male       4 years
# 124221          Normal        Dog  Intact Female       2 years
#
#                                         breed        color  intakeyear
# 0                                  Beagle Mix     Tricolor        2019
# 1                    English Springer Spaniel  White/Liver        2015
# 2                                 Basenji Mix  Sable/White        2016
# 3                      Domestic Shorthair Mix       Calico        2013
# 4       Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014
# ...                                       ...          ...         ...
# 124211                     Domestic Shorthair  White/Black        2021
# 124214                Flat Coat Retriever Mix        Black        2021
# 124218                  Dachshund/Rat Terrier  Brown/White        2021
# 124219                        German Shepherd  Brown/Black        2021
# 124221                        German Shepherd  Brown/Black        2021
#
# [86507 rows x 12 columns]

# %%
df.head(3)
# Out:
#   animalid     name            datetime                        foundlocation  \
# 0  A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1  A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2  A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
#
#   intaketype intakecondition animaltype  sexuponintake ageuponintake  \
# 0      Stray          Normal        Dog  Neutered Male       2 years
# 1      Stray          Normal        Dog  Spayed Female       8 years
# 2      Stray          Normal        Dog    Intact Male     11 months
#
#                       breed        color  intakeyear
# 0                Beagle Mix     Tricolor        2019
# 1  English Springer Spaniel  White/Liver        2015
# 2               Basenji Mix  Sable/White        2016

# %%
# Second example: animals where the animal type is not dog
df.loc[df['animaltype'] != 'Dog']
# Out:
#        animalid    name            datetime  \
# 3       A665644     NaN 2013-10-21 07:59:00
# 8       A818975     NaN 2020-06-18 14:53:00
# 9       A774147     NaN 2018-06-11 07:45:00
# 10      A731435  *Casey 2016-08-08 17:52:00
# 14      A790209   Ziggy 2019-03-06 14:31:00
# ...         ...     ...                 ...
# 124203  A830137  *Sohjo 2021-03-03 12:26:00
# 124207  A830413     NaN 2021-03-09 11:10:00
# 124210  A830385   Eevee 2021-03-08 15:46:00
# 124211  A830432     NaN 2021-03-09 12:50:00
# 124217  A830428     NaN 2021-03-09 12:07:00
#
#                                         foundlocation       intaketype  \
# 3                                         Austin (TX)            Stray
# 8               Braker Lane And Metric in Travis (TX)            Stray
# 9                       6600 Elm Creek in Austin (TX)            Stray
# 10                                        Austin (TX)  Owner Surrender
# 14                  4424 S Mopac Expwy in Austin (TX)    Public Assist
# ...                                               ...              ...
# 124203               3401 Palomar Lane in Austin (TX)            Stray
# 124207  517 South Pleasant Valley Road in Austin (TX)         Wildlife
# 124210            3308 Thompson Street in Austin (TX)            Stray
# 124211                                    Austin (TX)            Stray
# 124217              501 Strichen Drive in Travis (TX)         Wildlife
#
#        intakecondition animaltype  sexuponintake ageuponintake  \
# 3                 Sick        Cat  Intact Female       4 weeks
# 8               Normal        Cat    Intact Male       4 weeks
# 9              Injured        Cat  Intact Female       4 weeks
# 10              Normal        Cat  Neutered Male      5 months
# 14              Normal        Cat  Intact Female       4 years
# ...                ...        ...            ...           ...
# 124203         Nursing        Cat    Intact Male       3 weeks
# 124207            Sick      Other        Unknown       2 years
# 124210          Normal        Cat  Spayed Female       2 years
# 124211          Normal        Cat  Intact Female       2 years
# 124217            Sick      Other        Unknown       2 years
#
#                          breed              color  intakeyear
# 3       Domestic Shorthair Mix             Calico        2013
# 8           Domestic Shorthair        Cream Tabby        2020
# 9       Domestic Shorthair Mix        Black/White        2018
# 10      Domestic Shorthair Mix        Cream Tabby        2016
# 14      Domestic Shorthair Mix  Brown Tabby/White        2019
# ...                        ...                ...         ...
# 124203      Domestic Shorthair   White/Blue Tabby        2021
# 124207                  Coyote           Red/Gray        2021
# 124210      Domestic Shorthair              Black        2021
# 124211      Domestic Shorthair        White/Black        2021
# 124217                   Skunk        Black/White        2021
#
# [53717 rows x 12 columns]

# %%
# And a third - animals found before 2018
df.loc[df['intakeyear'] < 2018]
# Out:
#        animalid        name            datetime  \
# 1       A706918       Belle 2015-07-05 12:59:00
# 2       A724273     Runster 2016-04-14 18:43:00
# 3       A665644         NaN 2013-10-21 07:59:00
# 4       A682524         Rio 2014-06-29 10:38:00
# 5       A743852        Odin 2017-02-18 12:46:00
# ...         ...         ...                 ...
# 124089  A714665         Max 2016-01-29 12:41:00
# 124090  A670937  Sadee Lynn 2016-09-02 09:33:00
# 124091  A670937  Sadee Lynn 2014-01-16 12:20:00
# 124096  A670937  Sadee Lynn 2016-05-10 09:51:00
# 124205  A684992        Reno 2014-07-31 15:45:00
#
#                                  foundlocation       intaketype  \
# 1             9409 Bluegrass Dr in Austin (TX)            Stray
# 2           2818 Palomino Trail in Austin (TX)            Stray
# 3                                  Austin (TX)            Stray
# 4                800 Grove Blvd in Austin (TX)            Stray
# 5                                  Austin (TX)  Owner Surrender
# ...                                        ...              ...
# 124089           7601 Daffan Ln in Travis (TX)            Stray
# 124090   15877 Long Vista Drive in Austin (TX)    Public Assist
# 124091               38Th, I 35 in Austin (TX)            Stray
# 124096               805 W 10Th in Austin (TX)            Stray
# 124205  17308 Albert Voelker Rd in Travis (TX)            Stray
#
#        intakecondition animaltype  sexuponintake ageuponintake  \
# 1               Normal        Dog  Spayed Female       8 years
# 2               Normal        Dog    Intact Male     11 months
# 3                 Sick        Cat  Intact Female       4 weeks
# 4               Normal        Dog  Neutered Male       4 years
# 5               Normal        Dog  Neutered Male       2 years
# ...                ...        ...            ...           ...
# 124089          Normal        Dog    Intact Male        1 year
# 124090          Normal        Dog  Spayed Female       8 years
# 124091          Normal        Dog  Spayed Female       5 years
# 124096          Normal        Dog  Spayed Female       8 years
# 124205          Normal        Dog    Intact Male      4 months
#
#                                         breed        color  intakeyear
# 1                    English Springer Spaniel  White/Liver        2015
# 2                                 Basenji Mix  Sable/White        2016
# 3                      Domestic Shorthair Mix       Calico        2013
# 4       Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014
# 5                      Labrador Retriever Mix    Chocolate        2017
# ...                                       ...          ...         ...
# 124089                Chihuahua Shorthair Mix  White/Black        2016
# 124090                                 Beagle    White/Tan        2016
# 124091                                 Beagle    White/Tan        2014
# 124096                                 Beagle    White/Tan        2016
# 124205                       Catahoula/Beagle    White/Tan        2014
#
# [76788 rows x 12 columns]

# %%
df.loc[(df['name'].isna()) & (df['intaketype'] != 'Stray')]
# Out:
#        animalid name            datetime  \
# 23      A810994  NaN 2019-12-25 00:05:00
# 28      A722979  NaN 2016-03-24 16:39:00
# 42      A812244  NaN 2020-01-18 14:14:00
# 65      A698165  NaN 2015-03-06 18:48:00
# 71      A779334  NaN 2018-08-30 11:21:00
# ...         ...  ...                 ...
# 124192  A830343  NaN 2021-03-08 10:15:00
# 124195  A830403  NaN 2021-03-08 22:11:00
# 124202  A830398  NaN 2021-03-08 19:14:00
# 124207  A830413  NaN 2021-03-09 11:10:00
# 124217  A830428  NaN 2021-03-09 12:07:00
#
#                                         foundlocation       intaketype  \
# 23                     7900 Rm 1826 Rd in Travis (TX)         Wildlife
# 28                    4100 Westbank Dr in Austin (TX)         Wildlife
# 42                                        Travis (TX)  Owner Surrender
# 65                201 San Jacinto Blvd in Austin (TX)         Wildlife
# 71                      5004 Heflin Ln in Austin (TX)         Wildlife
# ...                                               ...              ...
# 124192               1513 Forest Trail in Austin (TX)         Wildlife
# 124195        9201 Burklund Farms Road in Travis (TX)         Wildlife
# 124202             2347 Douglas Street in Austin (TX)    Public Assist
# 124207  517 South Pleasant Valley Road in Austin (TX)         Wildlife
# 124217              501 Strichen Drive in Travis (TX)         Wildlife
#
#        intakecondition animaltype  sexuponintake ageuponintake  \
# 23              Normal      Other        Unknown       2 years
# 28              Normal      Other        Unknown        1 year
# 42              Normal        Dog    Intact Male       1 month
# 65              Normal      Other        Unknown       4 weeks
# 71             Injured      Other        Unknown       2 years
# ...                ...        ...            ...           ...
# 124192         Injured      Other        Unknown       2 years
# 124195         Injured      Other        Unknown        1 year
# 124202          Normal        Dog  Intact Female       6 years
# 124207            Sick      Other        Unknown       2 years
# 124217            Sick      Other        Unknown       2 years
#
#                               breed        color  intakeyear
# 23                              Bat        Brown        2019
# 28                          Bat Mix        Brown        2016
# 42               Labrador Retriever          Tan        2020
# 65                              Bat  Brown/Black        2015
# 71                          Raccoon   Gray/Black        2018
# ...                             ...          ...         ...
# 124192                      Raccoon        Brown        2021
# 124195                          Bat        Brown        2021
# 124202  Pit Bull/Labrador Retriever  Black/Brown        2021
# 124207                       Coyote     Red/Gray        2021
# 124217                        Skunk  Black/White        2021
#
# [8362 rows x 12 columns]

# %% [markdown]
# ## Let's Start to Answer Questions!

# %% [markdown]
# #### Question 1: What is the most common Animal Type?

# %%
# Let's explore the Animal Type column to find out
df['animaltype'].value_counts()
# Out:
# Dog          70505
# Cat          46483
# Other         6625
# Bird           587
# Livestock       22
# Name: animaltype, dtype: int64

# %%
# Another way - look above at describe, or run another describe
# 'Top' for an object column means 'most common'
df['animaltype'].describe()
# Out:
# count     124222
# unique         5
# top          Dog
# freq       70505
# Name: animaltype, dtype: object

# %% [markdown]
# #### Question 2: What is the most common dog breed to come into the shelter?

# %%
# Let's create a new df, dogs, for all dogs in the original data
dogs = df.loc[df['animaltype'] == 'Dog']

# %%
dogs.head()
# Out:
#   animalid     name            datetime                        foundlocation  \
# 0  A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1  A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2  A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 4  A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
# 5  A743852     Odin 2017-02-18 12:46:00                          Austin (TX)
#
#         intaketype intakecondition animaltype  sexuponintake ageuponintake  \
# 0            Stray          Normal        Dog  Neutered Male       2 years
# 1            Stray          Normal        Dog  Spayed Female       8 years
# 2            Stray          Normal        Dog    Intact Male     11 months
# 4            Stray          Normal        Dog  Neutered Male       4 years
# 5  Owner Surrender          Normal        Dog  Neutered Male       2 years
#
#                                    breed        color  intakeyear
# 0                             Beagle Mix     Tricolor        2019
# 1               English Springer Spaniel  White/Liver        2015
# 2                            Basenji Mix  Sable/White        2016
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray        2014
# 5                 Labrador Retriever Mix    Chocolate        2017

# %%
# Now it's easier to look at common dog breeds
dogs['breed'].value_counts()
# Out:
# Pit Bull Mix                           8413
# Labrador Retriever Mix                 6866
# Chihuahua Shorthair Mix                6238
# German Shepherd Mix                    3005
# Australian Cattle Dog Mix              1511
#                                        ...
# Dachshund Longhair/Miniature Poodle       1
# Australian Cattle Dog/Vizsla              1
# Anatol Shepherd/Boxer                     1
# Australian Shepherd/Greyhound             1
# Shiba Inu/Chow Chow                       1
# Name: breed, Length: 2328, dtype: int64

# %% [markdown]
# #### Question 3: What percentage of animals have come into the shelter in a condition other than "Normal"?

# %%
# Need to explore the proper column
num_not_normal = len(df.loc[df['intakecondition'] != 'Normal'])

# %%
# Want to use pandas to calculate, not inputting number manually
num_not_normal
# Out:
# 16196

# %%
# Calculate percentage
len(df)
# Out:
# 124222

# %%
num_not_normal / len(df)
# Out:
# 0.13037948189531645

# %%
# Other way to calculate
num_normal = df['intakecondition'].value_counts()['Normal']

# %%
1 - (num_normal / len(df))
# Out:
# 0.13037948189531645

# %% [markdown]
# ## Now - Outtake Data!
#
# Let's explore together if we have time! If not - extra credit!
